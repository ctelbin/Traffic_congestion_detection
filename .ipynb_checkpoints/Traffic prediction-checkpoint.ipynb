# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras

# %%
df = pd.read_csv('data.csv',index_col='Date',parse_dates=True)
df.index.freq='MS'

# %%
df.head()
# Out:
#             Traffic Congestion Rate
# Date
# 1962-01-01                      589
# 1962-02-01                      561
# 1962-03-01                      640
# 1962-04-01                      656
# 1962-05-01                      727

# %%
df.plot(figsize=(12,6)) #plotting the figure size and general trend increasing with the time period
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose #views the exact seasonal rate or seasonal trend , decomposes different part of time series.

# %%
results = seasonal_decompose(df['Traffic Congestion Rate']) #select which coloumn you need decomposition, general increasing trend with time
results.plot();

# %%
len(df)
# Out:
# 168

# %%
train = df.iloc[:72] #uses last 12 months as the testing side , prediction on last 12 months
test = df.iloc[72:]

# %%
from sklearn.preprocessing import MinMaxScaler  #used to convert a dataset into a scale of 0 to 1
scaler = MinMaxScaler()

# %%
df.head(),df.tail() #There will be a change of magnitude from a particular range to next range , we may get confused so we change it into a length of 0 to 1
# Out:
# (            Traffic Congestion Rate
#  Date
#  1962-01-01                      589
#  1962-02-01                      561
#  1962-03-01                      640
#  1962-04-01                      656
#  1962-05-01                      727,
#              Traffic Congestion Rate
#  Date
#  1975-08-01                      858
#  1975-09-01                      817
#  1975-10-01                      827
#  1975-11-01                      797
#  1975-12-01                      843)

# %%
scaler.fit(train) #This will check the mean value maximum value and all , transforming both scalar and testing part
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
scaled_train[:10] #prints the value in a range of 0 to 1
# Out:
# array([[0.12676056],
#        [0.02816901],
#        [0.30633803],
#        [0.36267606],
#        [0.61267606],
#        [0.50704225],
#        [0.30633803],
#        [0.16197183],
#        [0.0528169 ],
#        [0.08450704]])

# %%
from keras.preprocessing.sequence import TimeseriesGenerator #TimesseriesGenerator is used to predict what will happen in the upcoming months

# %%
# define generator
n_input = 3
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
X,y = generator[0] #3 values are inserted, then will predict the next value
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.12676056 0.02816901 0.30633803]
# Predict this y:
#  [[0.36267606]]

# %%
X.shape
# Out:
# (1, 3, 1)

# %%
# We do the same thing, but now instead for 12 months
n_input = 12
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# define model
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 100)               40800
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
model.fit(generator,epochs=50)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 2/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 3/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 4/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 5/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 6/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 7/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 8/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0052
# Epoch 9/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 10/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 11/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 12/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 13/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 14/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 15/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 16/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 17/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 18/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 19/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0022 - 0s 4ms/step - loss: 0.0025
# Epoch 20/50
# 60/60 [==============================] - ETA: 0s - loss: 0.003 - 0s 4ms/step - loss: 0.0031
# Epoch 21/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 22/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0031
# Epoch 23/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 24/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 25/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 26/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 27/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 28/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0046A: 0s - loss: 0.00
# Epoch 29/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 30/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 31/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 32/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 33/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 34/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 35/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 36/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 37/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 38/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 39/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0036
# Epoch 40/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0034
# Epoch 41/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 42/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 43/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 44/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 45/50
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 46/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 47/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 48/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 49/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 50/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0018- ETA: 0s - loss: 0.0

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
last_train_batch = scaled_train[-12:]

# %%
last_train_batch = last_train_batch.reshape((1, n_input, n_features))

# %%
model.predict(last_train_batch)
# Out:
# array([[0.59805167]], dtype=float32)

# %%
model.predict(last_train_batch)
# Out:
# array([[0.59805167]], dtype=float32)

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_predictions
# Out:
# [array([0.59805167], dtype=float32),
#  array([0.52775425], dtype=float32),
#  array([0.84013915], dtype=float32),
#  array([0.97151935], dtype=float32),
#  array([1.1087025], dtype=float32),
#  array([1.061324], dtype=float32),
#  array([0.8821769], dtype=float32),
#  array([0.6776013], dtype=float32),
#  array([0.5307369], dtype=float32),
#  array([0.5210241], dtype=float32),
#  array([0.47303903], dtype=float32),
#  array([0.5628624], dtype=float32),
#  array([0.6575449], dtype=float32),
#  array([0.67177504], dtype=float32),
#  array([0.9702392], dtype=float32),
#  array([1.1344811], dtype=float32),
#  array([1.1947246], dtype=float32),
#  array([1.1923177], dtype=float32),
#  array([1.0332036], dtype=float32),
#  array([0.7817758], dtype=float32),
#  array([0.610039], dtype=float32),
#  array([0.5804022], dtype=float32),
#  array([0.55543953], dtype=float32),
#  array([0.6300697], dtype=float32),
#  array([0.74639297], dtype=float32),
#  array([0.87416965], dtype=float32),
#  array([1.1513501], dtype=float32),
#  array([1.2076778], dtype=float32),
#  array([1.2287729], dtype=float32),
#  array([1.2697172], dtype=float32),
#  array([1.1919321], dtype=float32),
#  array([0.9122955], dtype=float32),
#  array([0.69653356], dtype=float32),
#  array([0.64882064], dtype=float32),
#  array([0.63866657], dtype=float32),
#  array([0.72117937], dtype=float32),
#  array([0.87050974], dtype=float32),
#  array([1.1327964], dtype=float32),
#  array([1.2298632], dtype=float32),
#  array([1.2348977], dtype=float32),
#  array([1.2312485], dtype=float32),
#  array([1.2755244], dtype=float32),
#  array([1.3070805], dtype=float32),
#  array([1.069526], dtype=float32),
#  array([0.8024109], dtype=float32),
#  array([0.7374244], dtype=float32),
#  array([0.7395085], dtype=float32),
#  array([0.84966004], dtype=float32),
#  array([1.1272713], dtype=float32),
#  array([1.2607613], dtype=float32),
#  array([1.2657813], dtype=float32),
#  array([1.2837359], dtype=float32),
#  array([1.2806511], dtype=float32),
#  array([1.264075], dtype=float32),
#  array([1.3355843], dtype=float32),
#  array([1.237129], dtype=float32),
#  array([0.9414656], dtype=float32),
#  array([0.8625008], dtype=float32),
#  array([0.8877128], dtype=float32),
#  array([1.1369469], dtype=float32),
#  array([1.3006474], dtype=float32),
#  array([1.2917925], dtype=float32),
#  array([1.2969347], dtype=float32),
#  array([1.301032], dtype=float32),
#  array([1.3179038], dtype=float32),
#  array([1.3010309], dtype=float32),
#  array([1.3367481], dtype=float32),
#  array([1.3652557], dtype=float32),
#  array([1.1253246], dtype=float32),
#  array([1.0561979], dtype=float32),
#  array([1.2056339], dtype=float32),
#  array([1.355973], dtype=float32),
#  array([1.3276314], dtype=float32),
#  array([1.3388885], dtype=float32),
#  array([1.3391281], dtype=float32),
#  array([1.3328812], dtype=float32),
#  array([1.3358463], dtype=float32),
#  array([1.3260555], dtype=float32),
#  array([1.2960737], dtype=float32),
#  array([1.3772424], dtype=float32),
#  array([1.3287809], dtype=float32),
#  array([1.3582945], dtype=float32),
#  array([1.3821912], dtype=float32),
#  array([1.3241335], dtype=float32),
#  array([1.336844], dtype=float32),
#  array([1.327639], dtype=float32),
#  array([1.3313253], dtype=float32),
#  array([1.3330288], dtype=float32),
#  array([1.3387202], dtype=float32),
#  array([1.3593799], dtype=float32),
#  array([1.32685], dtype=float32),
#  array([1.3043116], dtype=float32),
#  array([1.3126253], dtype=float32),
#  array([1.2656374], dtype=float32),
#  array([1.2949777], dtype=float32),
#  array([1.3229346], dtype=float32)]

# %%
test.head()
# Out:
#             Traffic Congestion Rate
# Date
# 1968-01-01                      717
# 1968-02-01                      696
# 1968-03-01                      775
# 1968-04-01                      796
# 1968-05-01                      858

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test['Traffic Congestion Rate'] = true_predictions
# Out:
# C:\Users\ctelb\AppData\Local\Temp/ipykernel_15688/301974197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Traffic Congestion Rate'] = true_predictions

# %%
test.plot(figsize=(14,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(test['Production'],test['Predictions']))
print(rmse)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Production'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15688/3613274921.py in <module>
#       1 from sklearn.metrics import mean_squared_error
#       2 from math import sqrt
# ----> 3 rmse=sqrt(mean_squared_error(test['Production'],test['Predictions']))
#       4 print(rmse)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Production'
